# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook,<font color= purple >  Data Science Tools  and Ecosystem </font> are summarized.

# %% [markdown]
# **Objectives**
# - List popular languages for Data Scientists
# - List commonly used libraries
# - Examples of evaluating arithmetic expressions in Python
# - Others

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b> Some of the popular languages that Data Scientists  use are:
# </b> </div>

# %% [markdown]
# > 1. Python
# 2. SQL
# 3. Java
# 4. Julia
# 5. Ruby

# %% [markdown]
# Some of the commonly used libraries 📚 used by Data Scientists include:

# %% [markdown]
# > 1. Pandas
# 2. NumPy
# 3. SciPy
# 4. Matplotlib

# %% [markdown]
# |Data Science Tools  |
# |--------------------|
# | Jupyter |
# | Jupyter Lab|
# | Apache Zeppelin|
# | RStudio |
# |Spyder|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Example:</b> 5+7
# </div>

# %%
5+7

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Example:</b> 7*9
# </div>

# %%
7*9

# %%
#  This a simple arithmetic expression to mutiply then add integers

(3*4)+5

# %%
#  This will convert 200 minutes to hours by diving by 60, rounded to whole hours by //

200//60

# %%
print("200 minutes is around 3 hours")

# %% [markdown]
# ## Author
# Teresa de la Parra
